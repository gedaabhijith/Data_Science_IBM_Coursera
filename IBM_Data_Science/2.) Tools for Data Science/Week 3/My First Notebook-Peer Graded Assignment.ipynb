# %% [markdown]
# # H1 My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **GP** **Anirudh**
# _Student_

# %% [markdown]
# _I am interested in Data Science because I am a technophile. I love using the latest and greatest technology. Whether that is hardware or software, I enjoy getting my hands on with these new technologies to see how that can enrich our lives._

# %% [markdown]
# # H3 In the below cell, my code prints "Hello World !".

# %%
x="Hello World !"
print(x)
# Out:
# Hello World !

# %% [markdown]
# <h1>HTML</h1>
# <p>HTML is a language for describing web pages.....</p>
#
# <hr>
#
# <h1>CSS</h1>
# <p>CSS defines how to display HTML elements.....</p>
#
# <hr>
#
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# <hr>
#
# <ol>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ol>
#
# <hr>
#
# <table style="width:100%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#     <th>Age</th>
#   </tr>
#   <tr>
#     <td>Jill</td>
#     <td>Smith</td>
#     <td>50</td>
#   </tr>
#   <tr>
#     <td>Eve</td>
#     <td>Jackson</td>
#     <td>94</td>
#   </tr>
# </table>
#
# <a href="https://www.w3schools.com/html/">Visit our HTML tutorial</a>
#
# <p>Version 2.0 is <strike>not yet available!</strike> now available!</p>
